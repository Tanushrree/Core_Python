# %%
#INTEGER - int
a = 7
print(a)
# Out:
# 7

# %%
type(a)
# Out:
# int

# %%
#FLOAT = float
a = 6.12
print(a)
type(a)
# Out:
# 6.12
# float

# %%
#STRING = str
a = "my name is tan"
print(a)
type(a)
# Out:
# my name is tan
# str

# %%
#BOOLEAN = bool
a = True
print(a)
type(a)
# Out:
# True
# bool

# %%
b = False
print(b)
type(b)
# Out:
# False
# bool

# %%
#COMPLEX = complex
a = 2+6j
print(a)
type(a)
# Out:
# (2+6j)
# complex
